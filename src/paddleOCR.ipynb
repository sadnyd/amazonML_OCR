# %%
import pandas as pd
import os
from tqdm import tqdm

# Enable tqdm with pandas
tqdm.pandas()

dataframe=pd.read_csv('../dataset/new_dataset.csv')

# %%
from paddleocr import PaddleOCR
from PIL import Image
import requests
from io import BytesIO
import numpy as np  # Ensure numpy is imported
import paddle

def ocr_from_image_url(image_url):
    try:
        # Set PaddlePaddle to use the maximum number of CPU threads
        #paddle.set_device('gpu')  # Explicitly set the device to GPU
        # Alternatively, you can use paddle.set_device('gpu:0') to specify a particular GPU
        
        # Initialize the PaddleOCR model with GPU enabled
        ocr = PaddleOCR(
            use_angle_cls=True, 
            lang='en', 
            use_gpu=True
        )

        # Download the image from the URL
        response = requests.get(image_url)
        response.raise_for_status()  # Check if the request was successful

        # Open the image using PIL
        image = Image.open(BytesIO(response.content))

        # Convert the image to a format compatible with PaddleOCR (NumPy array)
        image_np = np.array(image)

        # Perform OCR using PaddleOCR
        result = ocr.ocr(image_np)

        # Extract and concatenate text from the OCR result
        text = '\n'.join([line[1][0] for line in result[0]])
        print(text)
        return text

    except requests.exceptions.RequestException as e:
        return f"Error downloading image: {e}"
    except Exception as e:
        return f"Error processing image: {e}"

# %%
dataframe['paddleocr_output'] = dataframe['image_link'].progress_apply(ocr_from_image_url)
dataframe
# Out:
#   0%|          | 0/160 [00:00<?, ?it/s]
# ...
